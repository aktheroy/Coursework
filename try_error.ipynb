#   ['2021-09-30', -0.04643984311740596, -0.06314758754877434, 'Profit', 37.85],
#   ['2021-10-05', -0.036324785461098574, -0.07025578974422973, 'Profit', 62.8],
#   ['2021-10-11', -0.04119500750715538, -0.06436793581390143, 'Profit', 63.75],
#   ['2021-11-24', -0.030933204647142186, -0.03755125459876319, 'Loss', -10.45],
#   ['2021-12-22', -0.03092219497054709, -0.04442391072352738, 'Loss', -9.75],
#   ['2021-12-23', -0.028539465974082745, -0.04560502035928806, 'Loss', -9.85],
# ...

# %%
import pandas as pd
flat_data = [item for sublist in x for item in sublist]
df = pd.DataFrame(flat_data, columns=['Date', 'Var95', 'Var99', 'Profit-Loss', 'Change'])

# %%
raw_data = df

# %%
raw_data['Var95_mean'] = raw_data.groupby('Date')['Var95'].transform('mean')
raw_data['Var99_mean'] = raw_data.groupby('Date')['Var99'].transform('mean')

# %%
raw_data
# Out:
#           Date     Var95     Var99 Profit-Loss  Change  Var95_mean  Var99_mean
# 0   2021-06-03 -0.040003 -0.066182      Profit   32.35   -0.045351   -0.067960
# 1   2021-06-23 -0.041647 -0.056408      Profit   19.60   -0.038635   -0.054058
# 2   2021-06-24 -0.047346 -0.074022      Profit    9.00   -0.043981   -0.065902
# 3   2021-08-24 -0.040336 -0.074978        Loss   -7.05   -0.042162   -0.069977
# 4   2021-09-22 -0.049849 -0.079735      Profit    7.85   -0.045474   -0.067704
# ..         ...       ...       ...         ...     ...         ...         ...
# 70  2022-07-19 -0.035535 -0.057433        Loss  -60.90   -0.035032   -0.057276
# 71  2022-08-09 -0.033982 -0.052855      Profit   25.50   -0.037154   -0.050360
# 72  2022-08-12 -0.040376 -0.054308      Profit   46.05   -0.039682   -0.050750
# 73  2022-08-18 -0.030961       NaN        None     NaN   -0.034007   -0.058315
# 74  2023-03-22 -0.032420 -0.047202        Loss  -12.00   -0.036150   -0.057933
#
# [75 rows x 7 columns]

# %%
raw_data['Var95'] = raw_data['Var95_mean']
raw_data['Var99'] = raw_data['Var99_mean']

# %%
raw_data = raw_data.drop(['Var95_mean', 'Var99_mean'], axis=1)

# %%
raw_data = raw_data.to_dict(orient='records')

# %%
raw_data
# Out:
# [{'Date': '2021-06-03',
#   'Var95': -0.04535143340083538,
#   'Var99': -0.06795952246357369,
#   'Profit-Loss': 'Profit',
#   'Change': 32.35},
#  {'Date': '2021-06-23',
#   'Var95': -0.03863527318810671,
#   'Var99': -0.05405791984190658,
#   'Profit-Loss': 'Profit',
#   'Change': 19.6},
#  {'Date': '2021-06-24',
#   'Var95': -0.04398122688972074,
#   'Var99': -0.06590169749721127,
#   'Profit-Loss': 'Profit',
#   'Change': 9.0},
#  {'Date': '2021-08-24',
#   'Var95': -0.04216167175493089,
#   'Var99': -0.06997682864203883,
#   'Profit-Loss': 'Loss',
#   'Change': -7.05},
#  {'Date': '2021-09-22',
#   'Var95': -0.04547436009941997,
#   'Var99': -0.06770370536087408,
#   'Profit-Loss': 'Profit',
#   'Change': 7.85},
#  {'Date': '2021-09-29',
#   'Var95': -0.04344331505545757,
#   'Var99': -0.06385563649237826,
#   'Profit-Loss': 'Profit',
#   'Change': 40.3},
#  {'Date': '2021-09-30',
#   'Var95': -0.03957021030102228,
#   'Var99': -0.06308306760178803,
#   'Profit-Loss': 'Profit',
# ...
